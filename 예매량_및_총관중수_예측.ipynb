# %%
for i in range(0,len(test)):
    pred_reservation_n_total(X_test, i)
# Out:
# Competition Date:  2019-03-29 00:00:00
# 총관중수:  [12587.49252441]
#
# Competition Date:  2019-03-30 00:00:00
# 총관중수:  [19741.42788414]
#
# Competition Date:  2019-03-31 00:00:00
# 총관중수:  [18674.39813804]
#
# Competition Date:  2019-04-05 00:00:00
# 총관중수:  [8269.089649]
#
# Competition Date:  2019-04-06 00:00:00
# 총관중수:  [16168.44063642]
#
# Competition Date:  2019-04-07 00:00:00
# 총관중수:  [13883.11701148]
#
# Competition Date:  2019-04-16 00:00:00
# 총관중수:  [10166.95732617]
#
# Competition Date:  2019-04-17 00:00:00
# 총관중수:  [9212.99137959]
#
# Competition Date:  2019-04-18 00:00:00
# 총관중수:  [9946.13380357]
#
# Competition Date:  2019-04-23 00:00:00
# 총관중수:  [3781.46164466]
#
# Competition Date:  2019-04-24 00:00:00
# 총관중수:  [4248.00335847]
#
# Competition Date:  2019-04-25 00:00:00
# 총관중수:  [4707.47751599]
#
# Competition Date:  2019-04-26 00:00:00
# 총관중수:  [4423.66239496]
#
# Competition Date:  2019-04-27 00:00:00
# 총관중수:  [9301.8166238]
#
# Competition Date:  2019-04-28 00:00:00
# ...
